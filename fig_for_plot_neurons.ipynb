# %% [markdown]
# ## notes for neuronvis
# 1, you can download neuronvis in https://gitee.com/bigduduwxf/neuron-vis.
# 2, remember to download the resource file：http://bap.cebsit.ac.cn/bap/neuronVis/resource.zip.
#
# ## notes for neruons
# 1, you can download the swc files for each neuron in the https://www.braindatacenter.cn/datacenter/web/#/dataSet/details?id=1800731789745954817.
# 2, we recommend you mirrow the neurons in the same brain side using the following code.

# %%
import pandas as pd
import os,sys,glob,random
from tqdm import tqdm
import re

# %%
os.chdir(r"J:\BLA_three_types\cluster")

# %%
# load the neuron infor
dfneuron = pd.read_csv("All_soma_infor_HY_neurons.csv",index_col=0)

# %%
dfneuron = pd.read_excel(r"BLA_3_cluster5.xlsx",index_col =0)

# %%
dfneuron
# Out:
#                    cluster
# file
# 251034_010_Vglut1        5
# 234172_015_Crh           3
# 221058_038_Sst           1
# 221058_107_Sst           3
# 221297_038_Sst           1
# 234172_031_Crh           3
# 252460_132_Sst           2
# 221058_040_Sst           2
# 234172_016_Crh           1
# 242655_057_Sst           3
# 234172_017_Crh           1
# 251039_029_Vglut1        5
# 230058_076_Sst           1
# 230058_078_Sst           1
# 252459_079_Sst           2
# 230058_074_Sst           1
# 251039_021_Vglut1        5
# 251034_001_Vglut1        5
# 234172_020_Crh           3
# 221058_071_Sst           2
# 221297_036_Sst           1
# 221058_104_Sst           3
# 252459_074_Sst           3
# 234172_019_Crh           3
# 221297_037_Sst           1
# 230058_073_Sst           2
# 234172_122_Crh           3
# 234172_086_Crh           3
# 251039_020_Vglut1        5
# 251039_033_Vglut1        5
# 234172_021_Crh           3
# 221058_088_Sst           2
# 251039_031_Vglut1        4
# 221058_113_Sst           2
# 251034_003_Vglut1        4
# 251034_004_Vglut1        5
# 234172_034_Crh           3
# 251039_022_Vglut1        3

# %%
import pandas as pd
import os,sys,glob,random
from tqdm import tqdm
sys.path.append(r"D:\python\neuron-vis\neuronVis")  # the neuron-vis folder
import Visual as nv

# %%
df = pd.DataFrame(os.listdir(r"F:\HIP\ACB\mirrow"))
df["file"] = [item[0:-4] for item in df[0].tolist()]
df.set_index("file",inplace=True)
dfneuron = df

# %%
# load the neuron infor
dfneuron = pd.read_csv("All_soma_infor_HY_neurons.csv",index_col=0)

# %%
dfneuron = pd.read_excel("BLA_3_cluster5.xlsx",index_col=0)

# %%
# load the view angle infor
left = dict(eye=(0.0,0.0,-15000),center=(0,0,0),up=(0,-1,0))
se = dict(eye=(-10000,-10000,-15000),center=(0,0,0),up=(0,-1,0))
top = dict(eye=(0,-15000,0),center=(0,0,0),up=(0,0,1))
front = dict(eye=(-15000,0,0),center=(0,0,0),up=(0,-1,0))
views = [left,se,top,front]
labels = ["left","se","top","front"]

# %%
os.chdir(r"J:\BLA_four_types")

# %%
dfneuron.cluster.unique()
# Out:
# array([1, 3, 2, 5, 4], dtype=int64)

# %%
# Extended Data Fig4-5 for each type
Datapth = r"J:\BLA_four_types\BLA_swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm(dfneuron.cluster.unique()):
    dfnew = dfneuron.loc[dfneuron.cluster == i]
    # dfnew = dfneuron.iloc[::3]
    
    for neuron in dfnew.index.to_list():
       
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("type_%d_%s.png"%((i),label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()
# Out:
# 100%|██████████| 5/5 [00:10<00:00,  2.17s/it]

# %%
## swc based plot
# fig1c
Datapath = r"J:\BLA_four_types\BLA_swc_mirrow"  #swc file path
neurons = os.listdir(Datapath)



# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
neuronvis.render.setBackgroundColor([1,1,1])
# for neuron in tqdm(dfneuron.index.to_list()[2:30]):   
for neuron in tqdm(neurons):
    ## If the name of your SWC file follows this format: 192710_002,
    ##  you can change dfneuron.index.to_list() to dfneuron.neurons.to_list().
    file = os.path.join(Datapath,neuron)
    # color=[random.random(),random.random(),random.random()]
    neuronvis.addNeuron(file,somaColor = [1.0,0.0,0.0],axonColor=[0.0,0.0,0.0],dendriteColor=[0.0,0.0,1.0])
    neuronvis.render.setBackgroundColor([1,1,1])
    neuronvis.render.setLineWidth(2)

    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("%s_%s.png"%(neuron[0:-4],label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()
# Out:
# 100%|██████████| 92/92 [01:11<00:00,  1.29it/s]

# %%
# fig1c
Datapth = r"F:\HIP\ACB\mirrow"  #swc file path
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
neuronvis.render.setBackgroundColor([1,1,1])
for neuron in tqdm(dfneuron.index.to_list()[2:30]):   
    ## If the name of your SWC file follows this format: 192710_002,
    ##  you can change dfneuron.index.to_list() to dfneuron.neurons.to_list().
    file = os.path.join(Datapth,neuron+".swc")
    color=[random.random(),random.random(),random.random()]
    neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
    neuronvis.render.setBackgroundColor([1,1,1])
    neuronvis.render.setLineWidth(2)

for label,view in zip(labels,views):
    neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
    neuronvis.render.savepng("test_neurons_%s.png"%(label))
neuronvis.clear(neurons=True,regions=True)
neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
dfneuron = pd.read_csv("991_soma_infor.csv",index_col=0)

# %%
file
# Out:
# 'F:\\all_neurons_0221\\swc_mirrow\\200783_003.swc'

# %%
# Extended Data Fig4-5 for each type
Datapth = r"F:\HIP\ACB\mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm([6]):
    # dfnew = dfneuron.loc[dfneuron.cluster == i]
    dfnew = dfneuron.iloc[::3]

    for neuron in dfnew.file.to_list():
        file = os.path.join(Datapth,neuron)
        # file = os.path.join(Datapth,neuron+".swc")
        color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("type_%d_%s.png"%((i),label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()
# Out:
# 100%|██████████| 1/1 [03:29<00:00, 209.75s/it]

# %%
#Extended Data Fig4-5 for each neuron
savedir = r"F:\HIP\ACB\plot"
Datapth = r"F:\HIP\ACB\mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)

# for i in tqdm(dfneuron.type.unique()):
#     dfnew = dfneuron.loc[dfneuron.type == i]

#     folder = "type_%d"%(i)    
#     foldernew = os.path.join(savedir,folder)

#     try:
#         os.mkdir(foldernew)
#     except:
#         print("dir exist")
        
for neuron in dfneuron.index.to_list():
    # file = os.path.join(Datapth,neuron)
    try:
        file = os.path.join(Datapth,neuron+".swc")
        # color=[random.random(),random.random(),random.random()]
        neuronvis.addRegion('CA1',[0,0.2,0.2])
        neuronvis.addRegion('ACB',[0.2,0.2,0])
        neuronvis.addNeuron(file,somaColor = [1.0,0.0,0.0],axonColor=[0.0,0.0,0.0],dendriteColor=[0.0,0.0,1.0])
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
        # neuronvis.addRegion('CA1',[0,0,0.5,0.2])
        # neuronvis.addRegion('ACB',[0.5,0,0,0.2])
        for label,view in zip(labels,views):
            neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
            neuronvis.render.savepng(os.path.join(savedir,neuron.split(".")[0]+"_%s.png"%label))
        neuronvis.clear(neurons=True,regions=True)
        neuronvis.neurons.clear()
    except:
        print("file not exist:",neuron)
neuronvis.render.closeWindow()
# Out:
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!

# %%
# fig 5
dforexin = pd.read_excel("orexin_soma_infor_type.xlsx",index_col=0)

# %%
# fig 5c
Datapth = r"F:\all_neurons_0221\swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)

for neuron in dforexin.index.to_list():
    # file = os.path.join(Datapth,neuron)
    file = os.path.join(Datapth,neuron+".swc")
    color=[random.random(),random.random(),random.random()]
    neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
    neuronvis.render.setBackgroundColor([1,1,1])
    neuronvis.render.setLineWidth(3)
for label,view in zip(labels,views):
    neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
    neuronvis.render.savepng("orexin_%s.png"%(label))
neuronvis.clear(neurons=True,regions=True)
neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
# fig 5e bottom
Datapth = r"F:\all_neurons_0221\swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm(dforexin.type.unique()):
    dfnew = dforexin.loc[dforexin.type == i]
    for neuron in dfnew.index.to_list():
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("orexin_type_%d_%s.png"%((i),label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
# fig 5e top
savedir = r".\Orexin_fig_plot"
Datapth = r"F:\all_neurons_0221\swc_mirrow"
neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
# neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm(dforexin.type.unique()):
# for i in [2]:
    dfnew = dforexin.loc[dforexin.type == i]

    folder = "type_%d"%(i)    
    foldernew = os.path.join(savedir,folder)
    
    try:
        os.mkdir(foldernew)
    except:
        print("dir exist")
        
    for neuron in dfnew.index.to_list():
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        # color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [1.0,0.0,0.0],axonColor=[0.0,0.0,0.0],dendriteColor=[0.0,0.0,1.0])
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
        for label,view in zip(labels,views):
            neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
            neuronvis.render.savepng(os.path.join(foldernew,neuron.split(".")[0]+"_%s.png"%label))
        neuronvis.clear(neurons=True,regions=True)
        neuronvis.neurons.clear()

        print(neuron)
neuronvis.render.closeWindow()

# %%
# fig6 
dfARH = pd.read_excel("Agrp_Pomc_ARH_type.xlsx",index_col=0)

# %%
# fig6b
Datapth = r"F:\all_neurons_0221\swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for geno in tqdm(dfARH.geno.unique()):
    dfnew = dfARH.loc[dfARH.geno == geno]
    for neuron in dfnew.index.to_list():
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("ARH_%s_%s.png"%(geno,label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
# fig 6e bottom
Datapth = r"F:\all_neurons_0221\swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm(dfARH.type.unique()):
    dfnew = dfARH.loc[dfARH.type == i]
    for neuron in dfnew.index.to_list():
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
    for label,view in zip(labels,views):
        neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
        neuronvis.render.savepng("ARH_type_%d_%s.png"%((i),label))
    neuronvis.clear(neurons=True,regions=True)
    neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
# fig 6e top
savedir = r".\\ARH_fig_plot"
Datapth = r"F:\all_neurons_0221\swc_mirrow"
# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
for i in tqdm(dfARH.type.unique()):
    dfnew = dfARH.loc[dfARH.type == i]

    folder = "type_%d"%(i)    
    foldernew = os.path.join(savedir,folder)
    
    try:
        os.mkdir(foldernew)
    except:
        print("dir exist")
        
    for neuron in dfnew.index.to_list():
        # file = os.path.join(Datapth,neuron)
        file = os.path.join(Datapth,neuron+".swc")
        # color=[random.random(),random.random(),random.random()]
        neuronvis.addNeuron(file,somaColor = [1.0,0.0,0.0],axonColor=[0.0,0.0,0.0],dendriteColor=[0.0,0.0,1.0])
        neuronvis.render.setBackgroundColor([1,1,1])
        neuronvis.render.setLineWidth(3)
        for label,view in zip(labels,views):
            neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
            neuronvis.render.savepng(os.path.join(foldernew,neuron.split(".")[0]+"_%s.png"%label))
        neuronvis.clear(neurons=True,regions=True)
        neuronvis.neurons.clear()
neuronvis.render.closeWindow()

# %%
# Extended Data Fig6b
Datapth = r"F:\all_neurons_0221\swc_mirrow"
dfneuron1 = dfneuron.loc[(dfneuron.type==4)&(dfneuron.geno=="Adcyap1")]
dfneuron2 = dfneuron.loc[(dfneuron.type==4)&(dfneuron.geno=="Penk")]


# neuronvis = nv.neuronVis(size=(1600,1000),renderModel=1)
neuronvis = nv.neuronVis(size=(1280,950),renderModel=1)
neuronvis.render.setBackgroundColor([1,1,1])
neuronvis.addRegion('CA1',[0,0,0.5])
for neuron in tqdm(dfneuron1.index.to_list()):
    # file = os.path.join(Datapth,neuron)
    file = os.path.join(Datapth,neuron+".swc")
    # color=[random.random(),random.random(),random.random()]
    color=[1,0,0]
    # neuronvis.addRegion('CA1',[0,0,0.5])
    neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
    # neuronvis.render.setBackgroundColor([1,1,1])
    # neuronvis.render.setLineWidth(2)

for neuron in tqdm(dfneuron2.index.to_list()):
    # file = os.path.join(Datapth,neuron)
    file = os.path.join(Datapth,neuron+".swc")
    # color=[random.random(),random.random(),random.random()]
    color=[16/255,112/255,16/255]
    neuronvis.addNeuron(file,somaColor = [0.0,0.0,0.0],axonColor= color,dendriteColor=color)
neuronvis.render.setBackgroundColor([1,1,1])
neuronvis.render.setLineWidth(2)

for label,view in zip(labels,views):
    neuronvis.render.setLookAt(eye=view["eye"],center=view["center"],up=view["up"]) 
    neuronvis.render.savepng("type4_adcyap1&Penk2_%s.png"%(label))
neuronvis.clear(neurons=True,regions=True)
neuronvis.neurons.clear()
neuronvis.render.closeWindow()
