# %%
from PIL import Image 
import numpy as np 
import nrrd
import os,glob
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import cv2,math
import matplotlib as mpl
import requests
import pandas as pd
from tqdm import tqdm

# %%
# %reset

# %%
# os.chdir(r"E:\allen_swc\soma")
somadata,header=nrrd.read(r"D:\python\CLA\annotation_10.nrrd")
dfarea = pd.read_excel(r"D:\python\CLA\brain_areas.xlsx",index_col=0)
# swc_files = glob.glob(r"E:\allen_swc\reg_swc\*.swc")

# %%
swc_files = glob.glob(r"J:\BLA_four_types\BLA_swc_mirrow\*.swc")

# %%
file2 = os.listdir(r"J:\BLA_Cck\BLA_soma")
ploted = [item[0:10] for item in file2]

# %%
swc_files[0][-14:-4] not in ploted
# Out:
# False

# %%
save = r"J:\BLA_four_types\BLA_swc_soma"
os.makedirs(save,exist_ok=True)

file2 = os.listdir(r"J:\BLA_four_types\BLA_swc_soma")
ploted = [item[0:10] for item in file2]

somainfor = []
for swc in tqdm(swc_files):
    if swc[-14:-4] not in ploted:
        dfneuron = pd.read_csv(swc,sep=" ",comment="#",header=None,names=["index","type","AP","DV","ML","radius","parent"])
        location = tuple((dfneuron.iloc[0,:][["AP","DV","ML"]].values//10).astype(int))
        areaname = dfarea.loc[dfarea.index == somadata[location]].region.values[0]

        # Image_slice = location[0]
        # image = somadata[Image_slice,:,:].astype("uint8")
        # # image = somadata[int(start+space/20),:,:].astype("uint8")
        # edges = cv2.Canny(image,10,25)
        # edges2 = 255-edges
        # # dfnew = dfplot_merfish.loc[(dfplot_merfish.AP>start*10)&(dfplot_merfish.AP<start*10+space)]
        # fig = plt.figure(figsize=(16,8),dpi=600)
        # ax = fig.add_subplot(1,1,1)
        # ax.imshow(edges2,cmap = 'gray')
        # ax.scatter(location[2],location[1],s=10,c="#ff0019",marker = "o",alpha = 1)  
        # # 添加左上角 label
        # plt.text(
        #     20, 35,                         # 坐标（x=5, y=15），稍微往下，不会贴边
        #     "somalocation:%s"%areaname,                # 显示的文字
        #     color="blue",                 # 字的颜色
        #     fontsize=20                  # 字号
        #     # bbox=dict(facecolor="black", alpha=0.9, pad=3
        #             )   # 背景框，避免看不清
        # # )


        # ax.axis("off")
        # if "2/3" in areaname:
        #     areaname = areaname.replace("2/3","23")
        # filename = os.path.basename(swc)[0:-4]+"_%s_%d_soma.png"%(areaname,Image_slice)
        # savepath = os.path.join(save,filename)
        somadict = {}
        somadict["neuron"] = os.path.basename(swc)[0:-4]
        somadict["areaname"] = areaname
        # somadict["slice"] = Image_slice
        somadict["AP"] = dfneuron.iloc[0,:][["AP"]].values[0]
        somadict["DV"] = dfneuron.iloc[0,:][["DV"]].values[0]
        somadict["ML"] = dfneuron.iloc[0,:][["ML"]].values[0]
        somainfor.append(somadict)
        # plt.savefig(savepath,dpi=300)
        # plt.close()   
    else:
        print("already ploted:",swc)
# Out:
# 100%|██████████| 92/92 [00:01<00:00, 88.06it/s]

# %%
dfsoma = pd.DataFrame(somainfor)

# %%
dfsoma["geno"] = [item.split("_")[-1] for item in dfsoma.neuron.tolist()]

# %%
dfsoma.to_excel("J:\BLA_four_types\soma_location\BLA_soma.xlsx")

# %%
save = r"J:\BLA_four_types\BLA_swc_soma"
os.makedirs(save,exist_ok=True)

file2 = os.listdir(r"J:\BLA_four_types\BLA_swc_soma")
ploted = [item[0:10] for item in file2]

somainfor = []
for swc in tqdm(swc_files):
    if swc[-14:-4] not in ploted:
        dfneuron = pd.read_csv(swc,sep=" ",comment="#",header=None,names=["index","type","AP","DV","ML","radius","parent"])
        location = tuple((dfneuron.iloc[0,:][["AP","DV","ML"]].values//10).astype(int))
        areaname = dfarea.loc[dfarea.index == somadata[location]].region.values[0]

        Image_slice = location[0]
        image = somadata[Image_slice,:,:].astype("uint8")
        # image = somadata[int(start+space/20),:,:].astype("uint8")
        edges = cv2.Canny(image,10,25)
        edges2 = 255-edges
        # dfnew = dfplot_merfish.loc[(dfplot_merfish.AP>start*10)&(dfplot_merfish.AP<start*10+space)]
        fig = plt.figure(figsize=(16,8),dpi=600)
        ax = fig.add_subplot(1,1,1)
        ax.imshow(edges2,cmap = 'gray')
        ax.scatter(location[2],location[1],s=10,c="#ff0019",marker = "o",alpha = 1)  
        # 添加左上角 label
        plt.text(
            20, 35,                         # 坐标（x=5, y=15），稍微往下，不会贴边
            "somalocation:%s"%areaname,                # 显示的文字
            color="blue",                 # 字的颜色
            fontsize=20                  # 字号
            # bbox=dict(facecolor="black", alpha=0.9, pad=3
                    )   # 背景框，避免看不清
        # )


        ax.axis("off")
        if "2/3" in areaname:
            areaname = areaname.replace("2/3","23")
        filename = os.path.basename(swc)[0:-4]+"_%s_%d_soma.png"%(areaname,Image_slice)
        savepath = os.path.join(save,filename)
        somadict = {}
        somadict["neuron"] = os.path.basename(swc)[0:-4]
        somadict["areaname"] = areaname
        # somadict["slice"] = Image_slice
        somadict["AP"] = dfneuron.iloc[0,:][["AP"]].values[0]
        somadict["DV"] = dfneuron.iloc[0,:][["DV"]].values[0]
        somadict["ML"] = dfneuron.iloc[0,:][["ML"]].values[0]
        somainfor.append(somadict)
        plt.savefig(savepath,dpi=300)
        plt.close()   
    else:
        print("already ploted:",swc)
# Out:
#  63%|██████▎   | 58/92 [01:14<00:43,  1.29s/it]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 48
#      46     somadict["ML"] = dfneuron.iloc[0,:][["ML"]].values[0]
#      47     somainfor.append(somadict)
# ---> 48     plt.savefig(savepath,dpi=300)
#      49     plt.close()
#      50 else:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\pyplot.py:1252, in savefig(*args, **kwargs)
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
#    1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# -> 1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\axes\_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:609, in _ImageBase.draw(self, renderer)
#     607         renderer.draw_image(gc, l, b, im, trans)
#     608 else:
# --> 609     im, l, b, trans = self.make_image(
#     610         renderer, renderer.get_image_magnification())
#     611     if im is not None:
#     612         renderer.draw_image(gc, l, b, im)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:912, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     909 transformed_bbox = TransformedBbox(bbox, trans)
#     910 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     911         else self.get_figure(root=True).bbox)
# --> 912 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     913                         magnification, unsampled=unsampled)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:529, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     525     output[..., 3] = output_alpha  # recombine rgb and alpha
#     527 # output is now either a 2D array of normed (int or float) data
#     528 # or an RGBA array of re-sampled input
# --> 529 output = self.to_rgba(output, bytes=True, norm=False)
#     530 # output is now a correctly sized RGBA array of uint8
#     531
#     532 # Apply alpha *after* if the input was greyscale without a mask
#     533 if A.ndim == 2:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\colorizer.py:367, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     337 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     338     """
#     339     Return a normalized RGBA array corresponding to *x*.
#     340
#    (...)
#     365
#     366     """
# --> 367     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\colorizer.py:158, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     156 if norm:
#     157     x = self.norm(x)
# --> 158 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159 return rgba
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\colors.py:740, in Colormap.__call__(self, X, alpha, bytes)
#     717 def __call__(self, X, alpha=None, bytes=False):
#     718     r"""
#     719     Parameters
#     720     ----------
#    (...)
#     738     RGBA values with a shape of ``X.shape + (4, )``.
#     739     """
# --> 740     rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     741     if not np.iterable(X):
#     742         rgba = tuple(rgba)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\colors.py:798, in Colormap._get_rgba_and_mask(self, X, alpha, bytes)
#     795 if bytes:
#     796     lut = (lut * 255).astype(np.uint8)
# --> 798 rgba = lut.take(xa, axis=0, mode='clip')
#     800 if alpha is not None:
#     801     alpha = np.clip(alpha, 0, 1)
#
# MemoryError: Unable to allocate 74.3 MiB for an array with shape (3696, 5267, 4) and data type uint8
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\ProgramData\miniconda3\lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\ProgramData\miniconda3\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\axes\_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:609, in _ImageBase.draw(self, renderer)
#     607         renderer.draw_image(gc, l, b, im, trans)
#     608 else:
# --> 609     im, l, b, trans = self.make_image(
#     610         renderer, renderer.get_image_magnification())
#     611     if im is not None:
#     612         renderer.draw_image(gc, l, b, im)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:912, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     909 transformed_bbox = TransformedBbox(bbox, trans)
#     910 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     911         else self.get_figure(root=True).bbox)
# --> 912 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     913                         magnification, unsampled=unsampled)
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:474, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     471     scaled_dtype = "f8" if da > 1e8 else "f4"
#     473 # resample the input data to the correct resolution and shape
# --> 474 A_resampled = _resample(self, A.astype(scaled_dtype), out_shape, t)
#     476 # if using NoNorm, cast back to the original datatype
#     477 if isinstance(self.norm, mcolors.NoNorm):
#
# File c:\ProgramData\miniconda3\lib\site-packages\matplotlib\image.py:207, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     205     else:
#     206         interpolation = 'hanning'
# --> 207 out = np.zeros(out_shape + data.shape[2:], data.dtype)  # 2D->2D, 3D->3D.
#     208 if resample is None:
#     209     resample = image_obj.get_resample()
#
# MemoryError: Unable to allocate 74.3 MiB for an array with shape (3696, 5267) and data type float32

# %%
dfsoma = pd.DataFrame(somainfor)

# %%
dfsoma

# %%
# %reset

# %%
save = r"J:\BLA_Cck\BLA_soma"
os.makedirs(save,exist_ok=True)
# somainfor = []
for swc in tqdm(swc_files[150:]):
    
    try:
        dfneuron = pd.read_csv(swc,sep=" ",comment="#",header=None,names=["index","type","AP","DV","ML","radius","parent"])
        location = tuple((dfneuron.iloc[0,:][["AP","DV","ML"]].values//10).astype(int))
        areaname = dfarea.loc[dfarea.index == somadata[location]].region.values[0]

        Image_slice = location[0]
        image = somadata[Image_slice,:,:].astype("uint8")
        # image = somadata[int(start+space/20),:,:].astype("uint8")
        edges = cv2.Canny(image,10,25)
        edges2 = 255-edges
        # dfnew = dfplot_merfish.loc[(dfplot_merfish.AP>start*10)&(dfplot_merfish.AP<start*10+space)]
        fig = plt.figure(figsize=(16,8),dpi=600)
        ax = fig.add_subplot(1,1,1)
        ax.imshow(edges2,cmap = 'gray')
        ax.scatter(location[2],location[1],s=10,c="#ff0019",marker = "o",alpha = 1)  
        # 添加左上角 label
        plt.text(
            20, 35,                         # 坐标（x=5, y=15），稍微往下，不会贴边
            "somalocation:%s"%areaname,                # 显示的文字
            color="blue",                 # 字的颜色
            fontsize=20                  # 字号
            # bbox=dict(facecolor="black", alpha=0.9, pad=3
                    )   # 背景框，避免看不清
        # )


        ax.axis("off")
        if "2/3" in areaname:
            areaname = areaname.replace("2/3","23")
        filename = os.path.basename(swc)[0:-4]+"_%s_%d_soma.png"%(areaname,Image_slice)
        savepath = os.path.join(save,filename)
        # somadict = {}
        # somadict["neuron"] = os.path.basename(swc)[0:-4]
        # somadict["areaname"] = areaname
        # # somadict["slice"] = Image_slice
        # somadict["AP"] = dfneuron.iloc[0,:][["AP"]].values[0]
        # somadict["DV"] = dfneuron.iloc[0,:][["DV"]].values[0]
        # somadict["ML"] = dfneuron.iloc[0,:][["ML"]].values[0]
        # somainfor.append(somadict)
        plt.savefig(savepath,dpi=300)
        plt.close()   
    except:
        print("file err:",swc)

# %%
dfsoma = pd.DataFrame(somainfor)
dfsoma.to_excel("soma_location_area.xlsx",index=False)

# %%
pics = os.listdir(r"E:\allen_swc\soma")

# %%
dfchose = pd.DataFrame(pics)

# %%
dfchose  = pd.read_excel(r"E:\allen_swc\soma_pics.xlsx",index_col=0)

# %%
chose = dfchose.loc[dfchose.label == 1]

# %%
import shutil
for pic in chose.index.tolist():
    src = os.path.join(r"E:\allen_swc\soma",pic)
    dst = os.path.join(r"E:\allen_swc\soma_chose",pic)
    shutil.copy(src,dst)

# %%
aa = "1060693328_17302_2634-X14565-Y41960_reg_ec_489_soma"

# %%
include = os.listdir(r"E:\allen_swc\soma_include")

# %%
dfcells = pd.DataFrame(include)

# %%
dfcells.columns = ["cellID"]

# %%
dfcells["file"] = [item.split("_reg")[0]+"_reg" for item in dfcells.cellID.tolist()]

# %%
dfcells.cellID.tolist()[0].split("_")[4]
# Out:
# 'ec'

# %%
dfcells["area"] = [item.split("_")[4] for item in dfcells.cellID.tolist()]

# %%
dfcells.to_excel(r"E:\allen_swc\soma_include.xlsx",index=False)

# %%
aa.split("reg")
# Out:
# ['1060693328_17302_2634-X14565-Y41960_', '_ec_489_soma']

# %%
dfchose.to_excel(r"E:\allen_swc\soma_pics.xlsx",index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
list(dfneuron.iloc[0,:][["AP","DV","ML"]].values//10)
# Out:
# [307.0, 459.0, 304.0]

# %%
# fig5b
bregma = True
plot_max = math.ceil(dfplot.AP.max()/10)
plot_min = int(dfplot.AP.min()/10)

try:
    os.mkdir("raw")
except:
    print("The folder already exist")

Image_slice = int((plot_max+plot_min)/2)
image = somadata[Image_slice,:,:].astype("uint8")
# image = somadata[int(start+space/20),:,:].astype("uint8")
edges = cv2.Canny(image,10,25)
edges2 = 255-edges
# dfnew = dfplot.loc[(dfplot.AP>start*10)&(dfplot.AP<start*10+space)]
fig = plt.figure(figsize=(16,8),dpi=600)
ax = fig.add_subplot(1,1,1)
ax.imshow(edges2,cmap = 'gray')
ax.scatter(dfplot.ML/10,dfplot.DV/10,s=4,c="#ff00ff",marker = "o",alpha = 1)  
ax.axis("off")

if bregma == False:
    plt.savefig(".\\raw\\soma_all_%d.jpg"%int(Image_slice),dpi=900)
else:
    plt.savefig(".\\raw\\soma_all_%d.jpg"%int(-(Image_slice*10-5472)/100),dpi=900)
plt.close()

# %%
# Fig 5f
bregma = True
hue_para = "type"
space = 350

dic_list = {1:'#E72119',2:'#1A793A',3:'#19479C',4:'#EAE83A',5:'#6EC6CA'}

plot_max = math.ceil(dfplot.AP.max()/10)
plot_min = int(dfplot.AP.min()/10)
print(plot_max)
print(plot_min)
try:
    os.mkdir("raw")
except:
    print("The folder already exist")
for start in range(plot_min,plot_max,int(space/10)):
    image = somadata[int(start+space/20),:,:].astype("uint8")
    edges = cv2.Canny(image,10,25)
    edges2 = 255-edges
    dfnew = dfplot.loc[(dfplot.AP>start*10)&(dfplot.AP<start*10+space)]
    fig = plt.figure(figsize=(16,8),dpi=600)
    ax = fig.add_subplot(1,1,1)
    ax.imshow(edges2,cmap = 'gray')
    for sep_i in dic_list:   
        dfsubplot = dfnew.loc[dfnew.loc[:,hue_para] == sep_i]
        ax.scatter(dfsubplot.ML/10,dfsubplot.DV/10,s=4,c=dic_list[sep_i],marker = "o",alpha = 1)  
    ax.axis("off")

    if bregma == False:
        plt.savefig(".\\raw\\type_%d.jpg"%int(start+space/20),dpi=900)
    else:
        plt.savefig(".\\raw\\type_%d.jpg"%int(-(start*10+space/2-5472)/100),dpi=900)
    plt.close()
# Out:
# 741
# 655
# The folder already exist

# %%
# Extended Data Fig13a
dfplot_merfish = pd.read_csv("all_orexin_soma_data.csv",index_col=0)
dfplot_merfish.columns = ["area","AP","DV","ML","slice"]
bregma = True
plot_max = math.ceil(dfplot_merfish.AP.max()/10)
plot_min = int(dfplot_merfish.AP.min()/10)

try:
    os.mkdir("raw")
except:
    print("The folder already exist")

Image_slice = int((plot_max+plot_min)/2)
image = somadata[Image_slice,:,:].astype("uint8")
# image = somadata[int(start+space/20),:,:].astype("uint8")
edges = cv2.Canny(image,10,25)
edges2 = 255-edges
# dfnew = dfplot_merfish.loc[(dfplot_merfish.AP>start*10)&(dfplot_merfish.AP<start*10+space)]
fig = plt.figure(figsize=(16,8),dpi=600)
ax = fig.add_subplot(1,1,1)
ax.imshow(edges2,cmap = 'gray')
ax.scatter(dfplot_merfish.ML/10,dfplot_merfish.DV/10,s=4,c="#ff00ff",marker = "o",alpha = 1)  
ax.axis("off")

if bregma == False:
    plt.savefig(".\\raw\\soma_all_merfish_%d.jpg"%int(Image_slice),dpi=900)
else:
    plt.savefig(".\\raw\\soma_all_merfish_%d.jpg"%int(-(Image_slice*10-5472)/100),dpi=900)
plt.close()
# Out:
# The folder already exist

# %%
os.makedirs("crop", exist_ok=True)

# %%
# HY
para = (2020*3,1450*3,2500*3,2020*3)
mirrow = False
# mirrow = True

# %%
filelist = glob.glob(".\\raw\\*")

# %%
# crop image
for file in filelist:
    filetmp = Image.open(file).crop(para)
    # filetmp = Image.open(file)
    filename = file.split("\\")[-1]
    # filetmp = filetmp.rotate(-90)
    if mirrow == True:
        filetmp = filetmp.transpose(Image.FLIP_LEFT_RIGHT)
        filetmp = filetmp.rotate(-90)
    filetmp.save(os.path.join(".\\crop",filename))
    filetmp.close()
# Out:
# C:\Users\zljia\AppData\Roaming\Python\Python310\site-packages\PIL\Image.py:3406: DecompressionBombWarning: Image size (103680000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
os.makedirs("edge", exist_ok=True)

# %%
filelist = glob.glob(".\\crop\\*")

# %%
# add edge
add = 8
for file in filelist:
    tmp1st = Image.open(file)
    x = int(tmp1st.size[0]+add*2)
    y = int(tmp1st.size[1]+add*2)
    result = Image.new(tmp1st.mode, (x,y),"black")
    # result = Image.new(tmp1st.mode, (x,y),"white")
    result.paste(tmp1st,box=(add,add))
    result.save(".\\edge\\%s"%(file.split("\\")[-1]))
    result.close()
