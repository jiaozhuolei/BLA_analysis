# %%
import pandas as pd
import os

# %%
os.chdir(r"J:\BLA_four_types\bilateral")

# %%
df = pd.read_csv("BLA_fourtype_plot_60_3.csv",index_col =0)

# %%
new_index = ['CEA_ipsi', 'BLA_ipsi', 'CP_ipsi', 'SI_ipsi', 'OT_ipsi', 'ACB_ipsi',
       'PL_ipsi', 'BMA_ipsi', 'ORB_ipsi', 'IA_ipsi',  'PB_ipsi',
       'EP_ipsi', 'AAA_ipsi', 'ACA_ipsi', 'BST_ipsi',  'PIR_ipsi',
       'MY_ipsi', 'LA_ipsi', 'MO_ipsi', 'COA_ipsi', 'AON_ipsi', 'AI_ipsi',
       'CA1_ipsi', 'MEA_ipsi', 'ILA_ipsi', 'PPN_ipsi', 'GPe_ipsi', 'TR_ipsi',
       'ENT_ipsi', 'FRP_ipsi', 'FS_ipsi',  'LHA_ipsi',
       'MRN_ipsi', 'SNr_ipsi','TT_ipsi', 'ECT_ipsi', 'PA_ipsi', 'LPO_ipsi',
       'MA_ipsi', 'PAA_ipsi',  
       'ProS_ipsi', 'SS_ipsi',
       'SNc_ipsi',  'SUT_ipsi', 'CLA_ipsi', 'ZI_ipsi', 'STN_ipsi',
       'EP_contra','CLA_contra','CP_contra','OT_contra','ACB_contra','FS_contra','SI_contra','MO_contra', 'SS_contra','ENT_contra','PIR_contra']

# %%
df[new_index].to_csv("BLA_fourtype_plot_60_4.csv")

# %%
dfp = pd.read_csv("BLA_neurons_0819_top60.csv",index_col=0)

# %%
dfp[new_index].to_csv("BLA_neurons_0819_top602.csv")

# %%
dfp[new_index]
# Out:
#                       CEA_ipsi      BLA_ipsi       CP_ipsi      SI_ipsi  \
# 221058_038_Sst     5631.989116   8255.673888   1156.533573  3576.375407
# 221058_040_Sst     1381.652315  15588.335166      0.000000     0.000000
# 221058_042_Sst     1899.077710      1.241491      0.000000     0.000000
# 221058_071_Sst        0.000000  16180.973792      0.000000     0.000000
# 221058_088_Sst      459.928514   3382.488350      0.000000     0.000000
# ...                        ...           ...           ...          ...
# 251039_031_Vglut1     0.000000   1312.766809  45732.837545   498.926171
# 251039_033_Vglut1   305.247710   9988.940591   1964.924881     0.000000
# 252459_074_Sst     4475.543910   1361.005486      0.000000     0.000000
# 252459_079_Sst     3470.165044   2690.807117   2523.105839     0.000000
# 252460_132_Sst     3087.389263   8735.203563    279.598242     0.000000
#
#                       OT_ipsi     ACB_ipsi      PL_ipsi      BMA_ipsi  \
# ...
