# %%
import pandas as pd
import os,glob,shutil

# %%
os.chdir(r"J:\BLA_four_types")

# %%
df = pd.read_csv(r"BLA_neuron_list_others.csv")

# %%
df["new"] = df["neurons"]+"_"+df["geno"]

# %%
df.to_excel("BLA_neuron_list_others.xlsx")

# %%
df2 = pd.read_excel("BLA_neuron_list_others.xlsx")

# %%
inpath = r"J:\BLA_four_types\BLA_Sun Lab_swc"
outpath = r"J:\BLA_four_types\BLA_new_swc"
for i,item in df2.iterrows():
    infile = os.path.join(inpath,item.neurons+".swc")
    outfile = os.path.join(outpath,item.new+".swc")
    shutil.copy(infile,outfile)
    pass

# %%
item.neurons
# Out:
# 'v1039-033-merge_t'

# %%
item.new
# Out:
# '251039_033_Vglut1'
