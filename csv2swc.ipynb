# %%
import glob,os
import pandas as pd

# %%
infiles = glob.glob(r"J:\BLA_four_types\csv_PFC_ways\csvs\*")

# %%
for file in infiles:
    dftmp = pd.read_csv(file,index_col=0)
    output = file.replace(".csv",".swc")
    # for i,item in dftmp.iterrows():
    o = open(output,"w")

    for i,item in dftmp.iterrows():
        records =  [None] * 7 
        records[0] = str(item.ID)
        records[1] = str(item.type)
        records[2] = str(item.AP)
        records[3] = str(item.DV)
        records[4] = str(item.ML)
        records[5] = str(item.R)
        records[6] = str(item.parent)

        o.write(records[0]+' '+records[1]+' '+records[2]+' '+records[3]+' '+records[4]+' '+records[5]+' '+records[6] + '\n')
    #             for record in records:
    #                 o.write(record+' ')
    o.close()

# %%
outfile
# Out:
# 'J:\\BLA_four_types\\csv_PFC_ways\\csvs\\251034_001_Vglut1_PFC_0.swc'

# %%
for i,item in dftmp.iterrows():
    print(i)
# Out:
# 0
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1169
# 1170
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# 1177
# 1178
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1192
# ...

# %%
item
# Out:
# ID               8807
# type                2
# AP            2607.48
# DV            3453.16
# ML            4409.74
# R            0.582031
# parent           8806
# area_ID           630
# area_name       ORBl5
# name_use          ORB
# bratch_ID         103
# side             left
# terminal            1
# Name: 8806, dtype: object

# %%
o = open(output,"w")

for i,item in dftmp.iterrows():
    records =  [None] * 7 
    records[0] = str(item.ID)
    records[1] = str(item.type)
    records[2] = str(item.AP)
    records[3] = str(item.DV)
    records[4] = str(item.ML)
    records[5] = str(item.R)
    records[6] = str(item.parent)

    o.write(records[0]+' '+records[1]+' '+records[2]+' '+records[3]+' '+records[4]+' '+records[5]+' '+records[6] + '\n')
#             for record in records:
#                 o.write(record+' ')
o.close()

# %%
dftmp2 = pd.read_csv(output,sep= " ")

# %%
dftmp2
# Out:
#          1  1.1  6173.379999999999   6106.2   2680.0  2.75390625    -1
# 0      263    2            6176.58  6107.06  2681.04    3.667969     1
# 1      264    2            6178.78  6107.90  2681.34    3.000000   263
# 2      265    2            6180.38  6108.12  2680.98    1.750000   264
# 3      266    2            6181.48  6106.44  2680.16    1.667969   265
# 4      267    2            6184.24  6103.60  2680.10    0.917969   266
# ...    ...  ...                ...      ...      ...         ...   ...
# 2152  8803    2            2614.10  3454.48  4408.78    1.000000  8802
# 2153  8804    2            2612.58  3452.98  4409.82    1.000000  8803
# 2154  8805    2            2610.44  3452.24  4409.60    1.000000  8804
# 2155  8806    2            2608.22  3452.46  4409.24    0.832031  8805
# 2156  8807    2            2607.48  3453.16  4409.74    0.582031  8806
#
# [2157 rows x 7 columns]
